# %%
import xarray as xr
import matplotlib.pyplot as plt

# %%
cd /g/data/tm70/ml0072/COMMON/git_repos/COSIMA_om3-scripts/expts_manager/product1_0.25deg/lexpt4_r14/archive/output015
# Out:
# /scratch/tm70/ml0072/access-om3/archive/lexpt4_r14-perturb-2d80c669/output015

# %%
vmo_file = !ls access-om3.mom6.3d.vmo.1mon.snap.1915.nc
vmo_file
# Out:
# ['access-om3.mom6.3d.vmo.1mon.snap.1915.nc']

# %%
vmo_file_ds = xr.open_mfdataset(vmo_file)

# %%
vmo_file_ds
# Out:
# <xarray.Dataset> Size: 4GB
# Dimensions:  (xh: 1440, yq: 1080, zl: 50, time: 12)
# Coordinates:
#   * xh       (xh) float64 12kB -279.9 -279.6 -279.4 -279.1 ... 79.38 79.62 79.88
#   * yq       (yq) float64 9kB -81.02 -80.92 -80.81 -80.71 ... 89.79 89.89 90.0
#   * zl       (zl) float64 400B 1.152 3.649 6.565 ... 5.034e+03 5.572e+03
#   * time     (time) object 96B 1915-02-01 00:00:00 ... 1916-01-01 00:00:00
# Data variables:
#     vmo      (time, zl, yq, xh) float32 4GB dask.array<chunksize=(1, 17, 360, 480), meta=np.ndarray>
# Attributes:
#     NumFilesInSet:  1
#     title:          ACCESS-OM3
#     grid_type:      regular
#     grid_tile:      N/A
